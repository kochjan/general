# %%
import TWSE

# %%
twse = TWSE.TWSE(['1101', '1102', '1103', '1104'])

# %%
a = twse.stock_enumeration()

# %%
a[3]
# Out:
#      3    1041臺銀鳳山  25.40      0    102  Unnamed: 5   4  1041臺銀鳳山.1  25.45  \
# 0    5    104D臺銀金山  25.40    692    434         NaN   6    1116企銀屏東  25.45
# 1    7    126Q宏遠高雄  25.45   3000      0         NaN   8    1520瑞士信貸  25.40
# 2    9    1520瑞士信貸  25.45      0   7000         NaN  10    1570港商法興  25.40
# 3   11    1570港商法興  25.45  18000      0         NaN  12    5387第一澎湖  25.40
# 4   13    5858統一嘉義  25.45      0   5000         NaN  14    592b元富板橋  25.45
# 5   15    592n元富西松  25.40      2      0         NaN  16    592q元富屏東  25.45
# 6   17    592u元富世貿  25.40      0      5         NaN  18    6160中國信託  25.45
# 7   19    6163中信託永  25.40    100      0         NaN  20    6464大昌新店  25.45
# 8   21    700h兆豐三民  25.40  10000      0         NaN  22    700H兆豐東門  25.40
# 9   23    700H兆豐東門  25.45  17000  21000         NaN  24    700P兆豐南京  25.40
# 10  25  8150台    新  25.40      0  17000         NaN  26  8150台    新  25.45
# ...
